# %%
#write a program to check if a number is positive
a = int(input("Enter the number: "))
if a > 0:
    print("Number is positive.")
else:
    print("Number is not a positive number.")
# Out:
# Enter the number:  5
# Number is positive.

# %%
#write a program to check if a number is negative
a = -5
if a < 0:
    print("Given number is negative.")
else:
    print("Given number is not negative.")
# Out:
# Given number is negative.

# %%
#write a program to check if the given number is 0
a = int(input("Enter the number: "))
if a == 0:
    print("Number is zero")
else:
    print("Number is not zero")
# Out:
# Enter the number:  5
# Number is not zero

# %%
#write a program to check if a number is even
a = int(input("Enter the number: "))
if a % 2 == 0:
    print("even number")        
else:
    print("not a even number")
# Out:
# Enter the number:  45
# not a even number

# %%
#write a program to check if a number is odd
a = 15
if a %2 !=0:
    print("odd number")
else:
    print("not a odd number")
# Out:
# odd number

# %%
#write a program to check if the number is greater than 10
a = int(input("Enter a number"))
if a > 10:
    print("a is greater than 10")
else:
    print("a is less than 10")
# Out:
# Enter a number 15
# a is greater than 10

# %%
#write a program to check if the number is less than or equal to 50
a = int(input("Enter the number"))
if a <= 50:
    print("a is less than 50")
else:
    print("a is greater than 50")
# Out:
# Enter the number 45
# a is less than 50

# %%
#write a program to check if a number is divisible by 5
a = 50
if a % 5 == 0:
    print("a is divisible by 5")
else: 
    print("a is not divisible by 5")
# Out:
# a is divisible by 5

# %%
#write a program to check if a is not divisible by 3
a = 21
if a %3 !=0:
    print("a is not divisible by 3")
if a % 3 == 0:
    print("a is divisible by 3")
# Out:
# a is divisible by 3

# %%
#write a program to check if a number is between 1 and 100
a = int(input("Enter the number:"))
if 1 <= a <= 100:
    print("number is between 1 and 100")
else:
    print("number is not between 1 and 100")
